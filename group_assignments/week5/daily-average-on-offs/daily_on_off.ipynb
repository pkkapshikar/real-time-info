# %%
import osmnx as ox

import pandas as pd

import plotly.express as px

import geopandas as gpd

import contextily as ctx

import matplotlib.pyplot as plt

import fiona

# %%
df = pd.read_csv('Daily Average Stop Totals by Route_Winter 2022 (for 19_20_51A).csv')
df
# Out:
# /tmp/ipykernel_597/35154245.py:1: DtypeWarning: Columns (0,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Daily Average Stop Totals by Route_Winter 2022 (for 19_20_51A).csv')
#         DAY_OF_WEEK  UNIQUE_STOP_NUMBER  511_STOP_ID  \
# 0           WEEKDAY            100110.0      56707.0
# 1               SAT            100110.0      56707.0
# 2               SUN            100110.0      56707.0
# 3           WEEKDAY            100170.0      57796.0
# 4               SAT            100170.0      57796.0
# ...             ...                 ...          ...
# 1028874         NaN                 NaN          NaN
# 1028875         NaN                 NaN          NaN
# 1028876         NaN                 NaN          NaN
# 1028877         NaN                 NaN          NaN
# 1028878         NaN                 NaN          NaN
#
#                            STOP_NAME ROUTE   ON  OFF  TOTAL
# ...

# %%
df.dropna()
# Out:
#     DAY_OF_WEEK  UNIQUE_STOP_NUMBER  511_STOP_ID                    STOP_NAME  \
# 0       WEEKDAY            100110.0      56707.0          ATLANTIC AV & #1105
# 1           SAT            100110.0      56707.0          ATLANTIC AV & #1105
# 2           SUN            100110.0      56707.0          ATLANTIC AV & #1105
# 3       WEEKDAY            100170.0      57796.0  ATLANTIC AV & CHALLENGER DR
# 4           SAT            100170.0      57796.0  ATLANTIC AV & CHALLENGER DR
# ..          ...                 ...          ...                          ...
# 663         SAT           9905360.0      51986.0           BROADWAY & 51ST ST
# 664         SUN           9905360.0      51986.0           BROADWAY & 51ST ST
# 665     WEEKDAY           9907630.0      52894.0           BROADWAY & 15TH ST
# 666         SAT           9907630.0      52894.0           BROADWAY & 15TH ST
# 667         SUN           9907630.0      52894.0           BROADWAY & 15TH ST
#
# ...
