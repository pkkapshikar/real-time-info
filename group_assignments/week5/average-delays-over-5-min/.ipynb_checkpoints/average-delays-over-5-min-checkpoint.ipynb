# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import plotly.express as px
import folium

# %%
shp_file = gpd.read_file('UniqueStops/UniqueStops_Fall22.shp')
shp_file.to_file('UniqueStops_Fall22.shp', driver='GeoJSON')
delays_19 = pd.read_csv('Line 19.csv')
delays_20 = pd.read_csv('Line 20.csv')
delays_51A = pd.read_csv('Line 51A.csv')

# %%
joined_geom_data_19 = delays_19.merge(shp_file, left_on='stop_code', right_on='stp_511_id', how = 'left')
joined_geom_data_20 = delays_20.merge(shp_file, left_on='stop_code', right_on='stp_511_id', how = 'left')
joined_geom_data_51A = delays_51A.merge(shp_file, left_on='stop_code', right_on='stp_511_id', how = 'left')

# %%
joined_geom_data_20
# Out:
#     Unnamed: 0  stop_id                              stop_name  stop_code  \
# 0            0      123                      Park St & Otis Dr      57537
# 1            1      125                  Park St & San Jose Av      58895
# 2            2      154                      2019 Shoreline Dr      57367
# 3            3      158               Willow St & Shoreline Dr      50510
# 4            4      160    Alameda South Shore Center & Kohl's      50300
# 5            5      168                Webster St & Lincoln Av      55549
# 6            6      171               Whitehall Pl & Willow St      51145
# 7            7      173             Willow St & Franciscan Way      57597
# 8            8      179               Park St & Buena Vista Av      56658
# 9            9       18                    Central Av & 8th St      54233
# 10          10      181               Park St & Santa Clara Av      52666
# 11          11      183                   Park St & Encinal Av      51444
# 12          12      186                Webster St & Central Av      55975
# 13          13      188            Webster St & Santa Clara Av      55444
# 14          14      190  Alameda South Shore Center At Park St      55519
# 15          15      203               Webster St & Atlantic Av      59400
# 16          16     2036      12th St & Broadway (12th St BART)      55557
# 17          17     2103                      23rd Av & 29th Av      55187
# 18          18      211        Webster St & Willie Stargell Av      50542
# 19          19     2606               E 12th St & Fruitvale Av      57785
# 20          20     2820              Fruitvale Av & Blossom St      55400
# 21          21     2821             Fruitvale Av & Castello St      54844
# 22          22     2822      Fruitvale Av & International Blvd      50112
# 23          23     2823               Fruitvale Av & E 16th St      51223
# 24          24     2824               Fruitvale Av & E 23rd St      58550
# 25          25     2828           Fruitvale Av & Foothill Blvd      55119
# 26          26     2830                Fruitvale Av & Logan St      55657
# 27          27     2831          Fruitvale Av & MacArthur Blvd      55595
# 28          28     2833              Fruitvale Av & Montana St      55622
# 29          29     2843                         Fruitvale BART      59000
# 30          30        3                    8th St & Portola Av      57793
# 31          31     3658                  12th St & Harrison St      58858
# 32          32     3667    Martin Luther King Jr Way & 11th St      58900
# 33          33     3696                   Harrison St & 8th St      50237
# 34          34       49      433 Grand St (Wood Middle School)      55410
# 35          35       50                Grand St & Shoreline Dr      59934
# 36          36     5232                   Park St & Clement Av      51027
# 37          37     5268               Fruitvale Av & School St      51269
# 38          38     5269            Fruitvale Av & Brookdale Av      51273
# 39          39     5270                Fruitvale Av & Lynde St      51274
# 40          40     5271               Fruitvale Av & E 18th St      51276
# 41          41     5322            Webster St & Buena Vista Av      51478
# 42          42     5336                         12th & Clay St      51528
# 43          43     5743            29th Av & Railroad Crossing      58856
# 44          44     6244                  Westline Dr & Otis Dr      52967
# 45          45     6245               Otis Dr & Larchmont Isle      52969
# 46          46     6247                     Otis Dr & Grand St      52975
# 47          47     6292           Shoreline Dr & Kitty Hawk Rd      53102
#
#    zone_id  2/12/23 14:59  OBJECTID stp_identi  stp_511_id  \
# 0        E     362.000000       120    0102810       57537
# 1        E     437.500000       122    0102830       58895
# 2        E     443.000000       151    0103450       57367
# 3        E     448.000000       154    0103500       50510
# 4        E     443.000000       156    0103600       50300
# 5        E     625.666667       160    0103830       55549
# 6        E     461.000000       163    0103910       51145
# 7        E     453.000000       165    0103960       57597
# 8        E     687.000000       169    0104170       56658
# 9        E     609.333333        27    0100860       54233
# 10       E     415.500000       171    0104210       52666
# 11       E     458.000000       173    0104230       51444
# 12       E     625.000000       176    0104280       55975
# 13       E     607.000000       178    0104310       55444
# 14       E     384.000000       182    0104390       55519
# 15       E     406.000000       192    0104600       59400
# 16       E     721.000000      1753    1000430       55557
# 17       E     254.333333      1808    1001390       55187
# 18       E     426.000000       197    0104800       50542
# 19       E     269.000000      2242    1008220       57785
# 20       E       0.000000      2376    1010920       55400
# 21       E       0.000000      2377    1010960       54844
# 22       E       0.000000      2378    1011000       50112
# 23       E       0.000000      2379    1011010       51223
# 24       E       0.000000      2380    1011050       58550
# 25       E       0.000000      2384    1011120       55119
# 26       E       0.000000      2386    1011140       55657
# 27       E       0.000000      2387    1011200       55595
# 28       E      10.000000      2389    1011230       55622
# 29       E       0.000000      2399    1011360       59000
# 30       E     813.500000         2    0100070       57793
# 31       E     714.000000      3060    1030750       58858
# 32       E       0.000000      3064    1030880       58900
# 33       E     371.000000      3090    1031500       50237
# 34       E     394.000000        58    0101380       55410
# 35       E     412.000000        59    0101390       59934
# 36       E     704.000000      4351    9902190       51027
# 37       E       0.000000      4382    9902660       51269
# 38       E       0.000000      4383    9902670       51273
# 39       E       0.000000      4384    9902680       51274
# 40       E       0.000000      4385    9902690       51276
# 41       E     402.000000      4433    9903290       51478
# 42       E     702.000000      4445    9903480       51528
# 43       E     272.000000      1828    1001730       58856
# 44       E     583.666667      4767    9907870       52967
# 45       E     620.666667      4768    9907880       52969
# 46       E     673.333333      4770    9907900       52975
# 47       E     420.000000      4807    9908270       53102
#
#                                stp_descri                      route  \
# 0                       Park St & Otis Dr                         20
# 1                   Park St & San Jose Av                  20 21 663
# 2                       2019 Shoreline Dr                   20 663 W
# 3                Willow St & Shoreline Dr                   20 663 W
# 4     Alameda South Shore Center & Kohl's                         20
# 5                 Webster St & Lincoln Av         20 78 96 851 W 51A
# 6                Whitehall Pl & Willow St                         20
# 7              Willow St & Franciscan Way                   20 663 W
# 8                Park St & Buena Vista Av                   20 21 OX
# 9                     Central Av & 8th St               20 631 663 W
# 10               Park St & Santa Clara Av                   20 21 OX
# 11                   Park St & Encinal Av                  20 21 663
# 12                Webster St & Central Av               20 631 663 W
# 13            Webster St & Santa Clara Av  20 78 631 663 851 O W 51A
# 14  Alameda South Shore Center At Park St                         20
# 15               Webster St & Atlantic Av          20 96 851 O W 51A
# 16      12th St & Broadway (12th St BART)             19 20 29 40 88
# 17                      23rd Av & 29th Av                   20 21 OX
# 18        Webster St & Willie Stargell Av             20 851 O W 51A
# 19               E 12th St & Fruitvale Av                   20 21 62
# 20              Fruitvale Av & Blossom St                   20 21 39
# 21             Fruitvale Av & Castello St                   20 21 39
# 22      Fruitvale Av & International Blvd                   20 21 39
# 23               Fruitvale Av & E 16th St                   20 21 39
# 24               Fruitvale Av & E 23rd St                   20 21 39
# 25           Fruitvale Av & Foothill Blvd                   20 21 39
# 26                Fruitvale Av & Logan St                   20 21 39
# 27          Fruitvale Av & MacArthur Blvd                   20 21 39
# 28              Fruitvale Av & Montana St                   20 21 39
# 29                         Fruitvale BART                   19 20 21
# 30                    8th St & Portola Av                   20 663 W
# 31                  12th St & Harrison St   19 20 29 33 40 88 96 840
# 32    Martin Luther King Jr Way & 11th St                         20
# 33                   Harrison St & 8th St                      19 20
# 34      433 Grand St (Wood Middle School)                     20 663
# 35                Grand St & Shoreline Dr                   20 663 W
# 36                   Park St & Clement Av                   20 21 OX
# 37               Fruitvale Av & School St                14 20 21 39
# 38            Fruitvale Av & Brookdale Av                14 20 21 39
# 39                Fruitvale Av & Lynde St                14 20 21 39
# 40               Fruitvale Av & E 18th St                   20 21 39
# 41            Webster St & Buena Vista Av         20 78 96 851 O 51A
# 42                         12th & Clay St             19 20 29 40 88
# 43            29th Av & Railroad Crossing                      20 21
# 44                  Westline Dr & Otis Dr                   20 663 W
# 45               Otis Dr & Larchmont Isle                   20 663 W
# 46                     Otis Dr & Grand St                   20 663 W
# 47           Shoreline Dr & Kitty Hawk Rd                   20 663 W
#
#                        geometry
# 0   POINT (-122.24873 37.75731)
# 1   POINT (-122.24584 37.76080)
# 2   POINT (-122.25837 37.75742)
# 3   POINT (-122.25664 37.75708)
# 4   POINT (-122.25277 37.75868)
# 5   POINT (-122.27665 37.77549)
# 6   POINT (-122.25483 37.75953)
# 7   POINT (-122.25588 37.75838)
# 8   POINT (-122.23983 37.76797)
# 9   POINT (-122.27325 37.77143)
# 10  POINT (-122.24213 37.76514)
# 11  POINT (-122.24462 37.76222)
# 12  POINT (-122.27681 37.77173)
# 13  POINT (-122.27671 37.77361)
# 14  POINT (-122.24954 37.75707)
# 15  POINT (-122.27637 37.78020)
# 16  POINT (-122.27262 37.80317)
# 17  POINT (-122.23598 37.77300)
# 18  POINT (-122.27639 37.78317)
# 19  POINT (-122.22676 37.77655)
# 20  POINT (-122.22054 37.78954)
# 21  POINT (-122.21762 37.79688)
# 22  POINT (-122.22609 37.77739)
# 23  POINT (-122.22452 37.78045)
# 24  POINT (-122.22206 37.78575)
# 25  POINT (-122.22297 37.78354)
# 26  POINT (-122.22122 37.78784)
# 27  POINT (-122.21634 37.80010)
# 28  POINT (-122.21703 37.79855)
# 29  POINT (-122.22474 37.77511)
# 30  POINT (-122.27280 37.76899)
# 31  POINT (-122.26877 37.80173)
# 32  POINT (-122.27726 37.80396)
# 33  POINT (-122.26991 37.79905)
# 34  POINT (-122.26275 37.76164)
# 35  POINT (-122.26384 37.75975)
# 36  POINT (-122.23841 37.76963)
# 37  POINT (-122.21819 37.79547)
# 38  POINT (-122.21921 37.79288)
# 39  POINT (-122.21983 37.79134)
# 40  POINT (-122.22386 37.78177)
# 41  POINT (-122.27654 37.77764)
# 42  POINT (-122.27489 37.80417)
# 43  POINT (-122.23088 37.77759)
# 44  POINT (-122.27147 37.76654)
# 45  POINT (-122.26769 37.76522)
# 46  POINT (-122.26262 37.76333)
# 47  POINT (-122.26129 37.75851)

# %%
def filter_for_delays(geom_data):
    geom_data = geom_data[geom_data.iloc[:,5] > 300]
    geom_data.columns.values[5] = "Average Delay"
    geom_data['lon'] = geom_data.geometry.apply(lambda p: p.x)
    geom_data['lat'] = geom_data.geometry.apply(lambda p: p.y)
    
    return geom_data

def generate_map(geom_data):
    filtered_geom_data = filter_for_delays(geom_data)
    fig = px.scatter_mapbox(filtered_geom_data,
                    lat='lat',
                    lon='lon',
                    zoom=12,
                    hover_name='stop_name',
                    hover_data=["Average Delay"],
                    mapbox_style="carto-positron")
    # options on the layout
    fig.update_layout(
        width = 800,
        height = 800,
        title_x=0.5
    )
    return fig

map_20 = generate_map(joined_geom_data_20)
map_51A = generate_map(joined_geom_data_51A)
map_20 = map_20.update_layout(title = 'Stops with Average Delays Over 5 Minutes for AC Transit Line 20')
map_51A = map_51A.update_layout(title = 'Stops with Average Delays Over 5 Minutes for AC Transit Line 51A')
# Out:
# /tmp/ipykernel_85/3446691411.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_85/3446691411.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_85/3446691411.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_85/3446691411.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
map_20

# %%
map_51A
